# %%
import bw2data as bd
import bw2io as bi
# from premise_gwp import add_premise_gwp  # only add if you want to use the premise

def base_setup_with_ecoinvent(
    project_name: str,
    db_name: str,
    db_loc: str,
    reparametrize_lognormals: bool = False,
    # setup_premise_gwp: bool = True, # only add if you want to use the premise
):
    """
    This method sets up a Brightway project with the ecoinvent database.

    Parameters
    ----------
    db_name : str
        The name of the database to import
    db_loc : str
        The location of the database to import (e.g. "C:/Users/.../ecoinvent 3.7.1_cutoff_ecoSpold02/datasets"))
    reparametrize_lognormals : bool, optional
        Whether or not to reparametrize lognormal distributions, by default True (recommended)
        This sets the mean of the lognormal distribution to static value of the LCA calculation.
        This is recommended because the default behavior of Brightway is to set the mean of the lognormal distribution to the value of the LCA calculation.
        This can lead to problems when performing Monte Carlo LCA calculations, because the mean of the lognormal distribution will change with each iteration.
        This can lead to a large number of iterations being required to reach convergence.
    setup_premise_gwp : bool, optional
        Whether or not to setup the premise_gwp method, by default True
        This method provides characterization factors for biogenic CO2 flows and hydrogen emissions to air.
    """

    # set the project, it will create a new project if it does not exist
    bd.projects.set_current(project_name)

    # imports biosphere flows, it will skip if already done
    bi.bw2setup()

    # get the path to the datasets folder
    db_dir = db_loc
    # give a name to the database
    data_base_name = db_name
    # check if the database is already in the project, and skip if yes
    if data_base_name in bd.databases:
        print("Database has already been imported")

    else:
        # import database
        db = bi.SingleOutputEcospold2Importer(
            db_dir,
            data_base_name,
            reparametrize_lognormals=reparametrize_lognormals,
        )

        db.apply_strategies()

        db.statistics()

        # db.drop_unlinked(True)
        # writes database into sql
        db.write_database()
        # Because some of the scenarios can yield LCI databases
        # containing net negative emission technologies (NET),
        # it is advised to account for biogenic CO2 flows when calculating
        # Global Warming potential indicators.
        # `premise_gwp` provides characterization factors for such flows.
        # It also provides factors for hydrogen emissions to air.
        # if setup_premise_gwp: # only add if you want to use the premise
        #     add_premise_gwp()

# %%
def get_method(method: str, include_premise_recommended: bool = False):
    """
    Give a name of an LCIA method and it will return the mid points of that method

    Parameters
    ----------
    method : str
        The name of the LCIA method
        for example, EN15804, ReCiPe 2016 v1.03, EF v3.1
    include_premise_recommended : bool
        If True, it will include the recommended methods from premise
    """
    methods = [m for m in bd.methods if method == m[0]]
    if include_premise_recommended:
        if (
            not ("IPCC 2021", "climate change", "GWP 100a, incl. H and bio CO2")
            in methods
            and ("IPCC 2021", "climate change", "GWP 100a, incl. H and bio CO2")
            in bd.methods
        ):
            methods.append(
                ("IPCC 2021", "climate change", "GWP 100a, incl. H and bio CO2")
            )
        if (
            not ("IPCC 2021", "climate change", "GWP 20a, incl. H and bio CO2")
            in methods
            and ("IPCC 2021", "climate change", "GWP 20a, incl. H and bio CO2")
            in bd.methods
        ):
            methods.append(
                ("IPCC 2021", "climate change", "GWP 20a, incl. H and bio CO2")
            )
        if (
            not ("IPCC 2021", "climate change", "GWP 100a, incl. H") in methods
            and ("IPCC 2021", "climate change", "GWP 100a, incl. H") in bd.methods
        ):
            methods.append(("IPCC 2021", "climate change", "GWP 100a, incl. H"))
        if (
            not ("IPCC 2021", "climate change", "GWP 20a, incl. H") in methods
            and ("IPCC 2021", "climate change", "GWP 20a, incl. H") in bd.methods
        ):
            methods.append(("IPCC 2021", "climate change", "GWP 20a, incl. H"))
    return methods

# %%
import bw2calc as bc
from tqdm import tqdm

def staticLCA(
    demands: list[dict[bd.Node, float]], methods: list[tuple]
) -> dict[int : dict[tuple, list[float]]]:
    """
    This method performs static LCA calculations for a list of demands and a list of methods.
    
    If you plan to run LCAs for activities form different databases, split the demands into separate lists.
    Each list of demands should contain demands for activities from the same database. that way the lci is only performed once for each database.
    And it runs much faster.

    Parameters
    ----------
    demands : list
        A list of demands, where each demand is a dictionary of the form:
        {
            activity name: amount
        }
        methods : list
        A list of methods, where each method is a tuple of the form:
        ("foo", "bar", "baz")
    """
    if len(methods) == 0:
        raise ValueError(
            "No methods were specified. Please specify at least one method to perform LCA calculations"
        )
    # assert that methods are lists of tuples
    assert (
        isinstance(methods, list)
        and isinstance(methods[0], tuple)
        and isinstance(methods[0][0], str)
    ), "Methods must be a list of tuples of strings"

    # Create all demands with a comprehension
    all_demands = {k: 1 for demand in demands for k in demand}
    # Initialize LCA object
    lca = bc.LCA(demand=all_demands, method=methods[0])
    lca.lci()
    # Create a list of characterization matrices
    C_matrices = {}

    for method in methods:
        lca.switch_method(method)
        C_matrices[method] = lca.characterization_matrix.copy()

    # Create container for results
    results = {}

    # Adding a progress bar for iterating through demands
    pbar = tqdm(total=len(demands), desc="Initializing LCA Calculations")
    for demand in demands:
        first_key = next(iter(demand))
        key_tuple = (
            first_key["name"],
            first_key["location"],
            first_key["code"],
            first_key["database"],
        )

        # Updating the progress bar description
        pbar.set_description(
            f"Performing LCA for activities of database: {key_tuple[3]}"
        )

        results[key_tuple] = {method: None for method in methods}

        # Convert to integer ids
        int_demand = {key.id: value for key, value in demand.items()}
        lca.lci(int_demand)
        for method in methods:
            lca.switch_method(method)
            results[key_tuple][method] = (C_matrices[method] * lca.inventory).sum()

        pbar.update(1)  # Update the progress bar after each demand is processed

    pbar.close()  # Close the progress bar after the loop

    return results

# %%
import numpy as np

def monteCarloLCA(
    demands: list[dict[bd.Node, float]],
    methods: list[tuple[str, str, str]],
    iterations: int = 20,
) -> dict[int : dict[tuple, np.ndarray]]:
    """
    This method performs Monte Carlo LCA calculations for a list of demands and a list of methods.

    Parameters
    ----------
    demands : list
        A list of demands, where each demand is a dictionary of the form:
        {
            activity name: amount
        }
    methods : list
        A list of methods, where each method is a tuple of the form:
        ("foo", "bar", "baz")
    iterations : int, optional
        The number of Monte Carlo iterations to perform, by default 20"""

    if len(methods) == 0:
        raise ValueError(
            "The methods list is empty, make sure you set the project in brightway, before calling the methods"
        )
    assert (
        isinstance(methods, list)
        and isinstance(methods[0], tuple)
        and isinstance(methods[0][0], str)
    ), "Methods must be a list of tuples of strings"
    # Create all demands with a comprehension
    all_demands = {k: 1 for demand in demands for k in demand}

    # Initialize LCA object
    lca = bc.LCA(demand=all_demands, method=methods[0], use_distributions=True)
    lca.lci()

    # Create characterization matrices using a loop
    C_matrices = {}
    for method in methods:
        lca.switch_method(method)
        C_matrices[method] = lca.characterization_matrix.copy()

    # Initialize container for results
    results = {}
    for demand in demands:
        first_key = next(iter(demand))
        key_tuple = (
            first_key["name"],
            first_key["location"],
            first_key["code"],
            first_key["database"],
        )
        results[key_tuple] = {method: [] for method in methods}

    # Adding a progress bar for the Monte Carlo iterations
    with tqdm(total=iterations, desc="Monte Carlo LCA Progress") as pbar:
        for iteration in range(1, iterations + 1):
            # Update progress bar with current iteration and demand
            pbar.set_description(
                f"Monte Carlo Iterations for activities of database: {key_tuple[3]}"
            )

            # Resample all matrices
            next(lca)
            for demand in demands:
                first_key = next(iter(demand))
                key_tuple = (
                    first_key["name"],
                    first_key["location"],
                    first_key["code"],
                    first_key["database"],
                )
                # Convert to integer ids
                int_demand = {key.id: value for key, value in demand.items()}
                lca.lci(int_demand)
                for method in methods:
                    lca.switch_method(method)
                    results[key_tuple][method].append(
                        (C_matrices[method] * lca.inventory).sum()
                    )

            pbar.update(1)  # Update the progress bar after each iteration

    # Convert lists to numpy arrays
    for key_tuple, methods_data in results.items():
        for method, values in methods_data.items():
            results[key_tuple][method] = np.array(values)

    return results

# %% [markdown]
# Use Examples:

# %%
bd.projects.set_current('Bhorizionv2')
db = bd.Database('ecoinvent391cutoff')
methods = get_method('EF v3.1')

# %%
act1 = {db.random(): 1}
act2 = {db.random(): 2}
act3 = {db.random(): 3}
activities = [act1, act2, act3]

# %%
static_results = staticLCA(activities, methods)
static_results
# Out:
# Performing LCA for activities of database: ecoinvent391cutoff: 100%|██████████| 3/3 [00:00<00:00,  8.22it/s]
# {('nutrient supply from NPK (15-15-15) fertiliser',
#   'RER',
#   'b97645a9e37a14b02e51e99fd23aa253',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): 0.04509539410013766,
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): 7.198595940029946,
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): 0.006028613388920665,
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): 7.175364612045179,
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): 0.017202714595846838,
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): 443.6237271396783,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): 442.4548028100465,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): 1.1689243296317728,
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): 101.59030795313936,
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): 0.0015310280512096934,
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): 0.008956054541474676,
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): 0.1552345691008566,
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 4.617144713823084e-09,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 3.282243354117996e-09,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 1.3349013597050879e-09,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 8.746272476307411e-08,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 8.228206912634736e-08,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 5.180655636726756e-09,
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): 0.5130350589370569,
#   ('EF v3.1', 'land use', 'soil quality index'): 47.22399447203638,
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): 8.724666507210364e-05,
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): 1.8822886255305252e-07,
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): 4.928042788190156e-07,
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): 0.02207626151415708,
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): 4.0322458279293745},
#  ('glued solid timber production',
#   'RoW',
#   'e8146e0c6b7efeb3b683449089e1d86a',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): 0.0008804983200878271,
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): 0.13033464092531327,
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): 0.00044032535471782844,
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): 0.12928241013243488,
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): 0.0006119054381605977,
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): 0.8981472898104754,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): 0.6951053509556914,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): 0.20304193885478403,
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): 1.7135939834222285,
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): 3.836859769680944e-05,
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): 0.0002974304587054697,
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): 0.0031579699266583616,
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 1.8713715496658475e-10,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 4.563747544855045e-11,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 1.414996795180343e-10,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 1.439300958945596e-09,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 1.3498234193537398e-09,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 8.947753959185665e-11,
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): 0.0077547228845431795,
#   ('EF v3.1', 'land use', 'soil quality index'): 183.00831112520677,
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): 3.2853073446030386e-07,
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): 1.5991740805399843e-09,
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): 4.1338153170239e-08,
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): 0.000978167204330276,
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): 0.04997249895363722},
#  ('market for fertilising, by rig fertiliser, sugarcane',
#   'GLO',
#   '2f62128504f42e441612edeb34605038',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): 1.373011137364707,
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): 154.93912441401145,
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): 0.10871712856831424,
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): 154.76045670131688,
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): 0.06995058412628322,
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): 1020.5966049093784,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): 983.5962581697212,
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): 37.00034673965729,
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): 2031.9126159041432,
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): 0.012931318911458581,
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): 0.5945416302533223,
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): 6.450548291733506,
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 1.0085968840071041e-07,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 6.432518156634233e-08,
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 3.653450683436807e-08,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): 7.892546439351653e-06,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): 7.832665133694677e-06,
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): 5.988130565697755e-08,
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): 1.7451177352326663,
#   ('EF v3.1', 'land use', 'soil quality index'): 477.4132498339508,
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): 0.0007748237979555574,
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): 2.54059250362614e-06,
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): 4.6475284222867655e-06,
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): 1.8967287653584721,
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): 8.376713120602592}}

# %%
monte_carlo_results = monteCarloLCA(activities, methods, iterations=10)
monte_carlo_results
# Out:
# Monte Carlo Iterations for activities of database: ecoinvent391cutoff: 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# {('nutrient supply from NPK (15-15-15) fertiliser',
#   'RER',
#   'b97645a9e37a14b02e51e99fd23aa253',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): array([0.03319037, 0.04109317, 0.03315345, 0.03490174, 0.03618526,
#          0.01808191, 0.06595275, 0.0426244 , 0.05201529, 0.02292007]),
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): array([4.39499944, 6.04056579, 6.33502278, 6.38848107, 5.59021242,
#          3.03579905, 9.10036936, 7.88694647, 8.39372372, 4.17739017]),
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): array([0.0044837 , 0.00486959, 0.00375547, 0.00585389, 0.00460894,
#          0.00217133, 0.01025613, 0.00939638, 0.00799772, 0.0023735 ]),
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): array([4.36637563, 6.01939376, 6.32356231, 6.37456912, 5.56439242,
#          3.02969072, 9.08424462, 7.85563141, 8.36756381, 4.1596681 ]),
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): array([0.02414011, 0.01630245, 0.00770501, 0.00805805, 0.02121106,
#          0.003937  , 0.00586861, 0.02191868, 0.0181622 , 0.01534857]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): array([305.44800649, 467.25005748, 755.51776228, 633.16418572,
#          390.37583922, 312.6391982 , 599.48901098, 749.58210663,
#          740.44131257, 197.42594787]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([304.61035332, 466.15498422, 754.6235352 , 632.20706171,
#          389.62765077, 312.17938632, 598.05483038, 747.79132424,
#          739.15825484, 196.63327808]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([0.83765317, 1.09507327, 0.89422708, 0.95712402, 0.74818845,
#          0.45981188, 1.43418061, 1.7907824 , 1.28305772, 0.79266979]),
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): array([ 59.58114146,  94.62648166,  86.62754203,  83.25136324,
#           70.87932932,  44.58678905, 118.33336027, 102.30839064,
#          109.85270057,  58.9481832 ]),
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): array([0.00107308, 0.0014394 , 0.00159904, 0.00097156, 0.00088696,
#          0.00044765, 0.00207116, 0.00056728, 0.00157594, 0.00059107]),
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): array([0.00546775, 0.00838529, 0.00715724, 0.00655766, 0.00713862,
#          0.0039053 , 0.01198033, 0.00960885, 0.01014191, 0.0048605 ]),
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): array([0.11490325, 0.13761657, 0.12066301, 0.11644605, 0.11816135,
#          0.06176862, 0.21002558, 0.1408266 , 0.17702547, 0.07559752]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([ 2.85060145e-08, -4.46441862e-09,  4.91157032e-08,  5.36978725e-08,
#           1.06841217e-08, -7.07335094e-09, -5.42358797e-08, -2.39773342e-08,
#          -5.50369278e-08,  1.56901346e-08]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([ 2.75675778e-08, -5.79924951e-09,  4.79770955e-08,  5.27818389e-08,
#           9.80942747e-09, -7.56166983e-09, -5.63654747e-08, -2.57233160e-08,
#          -5.70310691e-08,  1.48048428e-08]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([9.38436717e-10, 1.33483088e-09, 1.13860766e-09, 9.16033689e-10,
#          8.74694192e-10, 4.88318891e-10, 2.12959504e-09, 1.74598174e-09,
#          1.99414125e-09, 8.85291846e-10]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([ 6.52378828e-06,  1.10152141e-06,  1.52827395e-05,  1.58363701e-05,
#           2.49385685e-06, -5.32628089e-06, -3.58565267e-07, -5.68512465e-06,
#          -1.70929874e-05, -3.35389710e-07]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([ 6.51935642e-06,  1.10442077e-06,  1.52776752e-05,  1.58331596e-05,
#           2.50764082e-06, -5.33086675e-06, -3.69693299e-07, -5.69307108e-06,
#          -1.71040469e-05, -3.39506163e-07]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([ 4.43186374e-09, -2.89936113e-09,  5.06432743e-09,  3.21049251e-09,
#          -1.37839720e-08,  4.58585493e-09,  1.11280323e-08,  7.94643444e-09,
#           1.10594451e-08,  4.11645318e-09]),
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): array([0.40153405, 0.2935539 , 0.49975524, 0.40741355, 1.30854355,
#          0.35979147, 0.51859017, 0.35967948, 0.37915601, 0.29196111]),
#   ('EF v3.1',
#    'land use',
#    'soil quality index'): array([32.81064544, 48.45484484, 38.59325419, 32.60745095, 30.44708367,
#          15.1897411 , 67.75655791, 55.03169159, 45.83058618, 25.962145  ]),
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): array([ 9.54374413e-05, -6.85145428e-05,  6.87293940e-05, -1.85335085e-06,
#          -2.36729019e-04,  8.78419071e-05,  2.56220731e-04,  1.09405929e-04,
#           1.85267650e-04,  8.23223564e-05]),
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): array([1.09116840e-07, 1.77391456e-07, 1.40060600e-07, 1.09840553e-07,
#          1.33573287e-07, 9.57465419e-08, 2.01693409e-07, 1.79710558e-07,
#          2.10044355e-07, 1.02733040e-07]),
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): array([3.39242596e-07, 4.66266848e-07, 4.06865081e-07, 3.44994139e-07,
#          4.58073580e-07, 1.96971875e-07, 7.95393169e-07, 6.32289558e-07,
#          5.63783622e-07, 2.65195897e-07]),
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): array([0.01359336, 0.01975402, 0.01640668, 0.01513074, 0.01532301,
#          0.01045899, 0.03259318, 0.02683332, 0.02603965, 0.01353386]),
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): array([2.6194181 , 2.99409918, 3.44952107, 4.45161167, 2.40755713,
#          1.71049721, 5.34512494, 4.90309358, 5.95748683, 2.33645187])},
#  ('glued solid timber production',
#   'RoW',
#   'e8146e0c6b7efeb3b683449089e1d86a',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): array([0.00081056, 0.00105124, 0.00084742, 0.00084197, 0.000829  ,
#          0.0010366 , 0.00108652, 0.00083671, 0.00092024, 0.00098836]),
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): array([0.1310399 , 0.15942371, 0.12999035, 0.1178565 , 0.14903337,
#          0.13089197, 0.16927014, 0.13138481, 0.14728827, 0.12755069]),
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): array([0.00050054, 0.00037216, 0.00062594, 0.00035502, 0.00035712,
#          0.00047219, 0.00041862, 0.0004986 , 0.00048658, 0.00048276]),
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): array([0.12940089, 0.15849637, 0.12889016, 0.11704594, 0.14818771,
#          0.1299392 , 0.16812917, 0.12998901, 0.14604458, 0.12626038]),
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): array([0.00113846, 0.00055519, 0.00047424, 0.00045555, 0.00048854,
#          0.00048058, 0.00072235, 0.0008972 , 0.00075711, 0.00080755]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): array([ 29.72991927,   2.93255793,  72.8716343 ,  42.54225159,
#            4.12871088, -77.09829526,  -2.83408981,  -2.90516174,
#          -28.27469464, -17.58695258]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([ 29.50195782,   2.73813138,  72.6993266 ,  42.38561902,
#            4.00453706, -77.25391438,  -2.9559823 ,  -3.1032176 ,
#          -28.41732681, -17.87737563]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([0.22796145, 0.19442655, 0.1723077 , 0.15663257, 0.12417382,
#          0.15561912, 0.12189248, 0.19805586, 0.14263217, 0.29042305]),
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): array([1.72251903, 1.90650879, 1.81507777, 1.68011235, 1.62066991,
#          1.72153494, 2.07059448, 1.72897568, 2.18800763, 1.55780594]),
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): array([7.09178306e-05, 4.84126007e-05, 6.36567287e-05, 3.84981172e-05,
#          3.38824351e-05, 2.91372759e-05, 4.07068265e-05, 2.14334955e-05,
#          3.57313828e-05, 2.78586226e-05]),
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): array([0.00026234, 0.00036222, 0.00027479, 0.0002851 , 0.00029029,
#          0.0003461 , 0.00035433, 0.00026545, 0.00031438, 0.00037296]),
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): array([0.00277387, 0.00381286, 0.00298949, 0.00298405, 0.00296802,
#          0.00368154, 0.0037917 , 0.00278522, 0.00333168, 0.00403942]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([-5.85412406e-09,  3.44855570e-09,  1.45584951e-08,  1.91259294e-08,
#          -3.48766108e-09, -1.48954748e-08,  3.29580067e-09, -3.08776643e-08,
#          -2.96020834e-08,  8.02832526e-09]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([-5.97773128e-09,  3.29750315e-09,  1.43941649e-08,  1.90003438e-08,
#          -3.58195146e-09, -1.50222012e-08,  3.14830733e-09, -3.10004634e-08,
#          -2.97956008e-08,  7.87879663e-09]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([1.23607227e-10, 1.51052551e-10, 1.64330280e-10, 1.25585649e-10,
#          9.42903732e-11, 1.26726384e-10, 1.47493338e-10, 1.22799040e-10,
#          1.93517365e-10, 1.49528634e-10]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([ 2.62558990e-07,  8.13290887e-07,  4.97226158e-06,  4.35135238e-06,
#           3.53203101e-08, -5.79110708e-06,  1.50880552e-06, -4.11513961e-06,
#          -5.63000821e-06,  3.87063543e-08]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([ 2.62402643e-07,  8.13482129e-07,  4.97208376e-06,  4.35130093e-06,
#           3.58606100e-08, -5.79134683e-06,  1.50867678e-06, -4.11523440e-06,
#          -5.63028076e-06,  3.84964768e-08]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([ 1.56346389e-10, -1.91241717e-10,  1.77819090e-10,  5.14504513e-11,
#          -5.40299831e-10,  2.39747300e-10,  1.28739939e-10,  9.47887471e-11,
#           2.72549107e-10,  2.09877552e-10]),
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): array([0.0095979 , 0.00651804, 0.00859899, 0.00879353, 0.0179835 ,
#          0.01144524, 0.00585873, 0.00551325, 0.00472889, 0.00766564]),
#   ('EF v3.1',
#    'land use',
#    'soil quality index'): array([245.03279496, 199.09476497, 112.82563224, 155.36516414,
#          298.32533888, 131.12267311, 190.58232383, 135.40508211,
#          355.51113033, 185.11417907]),
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): array([ 2.17357065e-06, -4.88357511e-06,  2.08999940e-06, -2.02937945e-06,
#          -1.07641843e-05,  4.21340321e-06,  1.39990054e-06,  4.31261571e-07,
#           4.00601509e-06,  2.57329793e-06]),
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): array([1.40031567e-09, 1.62172477e-09, 1.65850725e-09, 1.53917701e-09,
#          1.66695394e-09, 1.73103031e-09, 1.96287163e-09, 1.56642128e-09,
#          1.88076614e-09, 1.95607633e-09]),
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): array([3.21676119e-08, 5.70155408e-08, 4.26689032e-08, 4.84699452e-08,
#          3.64557380e-08, 5.15135995e-08, 4.54650389e-08, 6.06370101e-08,
#          4.63956794e-08, 3.18943003e-08]),
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): array([0.0010152 , 0.00115473, 0.00087184, 0.00090965, 0.0010005 ,
#          0.00107741, 0.00122522, 0.00087981, 0.00110142, 0.00119166]),
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): array([0.04497824, 0.05374601, 0.05169744, 0.0462129 , 0.04727268,
#          0.05516564, 0.05227206, 0.0611731 , 0.0522435 , 0.05317733])},
#  ('market for fertilising, by rig fertiliser, sugarcane',
#   'GLO',
#   '2f62128504f42e441612edeb34605038',
#   'ecoinvent391cutoff'): {('EF v3.1',
#    'acidification',
#    'accumulated exceedance (AE)'): array([1.28499212, 1.32047796, 1.18122161, 1.1314874 , 1.29506787,
#          1.18795524, 1.37052726, 1.4987482 , 1.49996838, 1.68089916]),
#   ('EF v3.1',
#    'climate change',
#    'global warming potential (GWP100)'): array([130.63345693, 154.4134239 , 177.44722862, 151.55806931,
#          166.17642644, 190.82557888, 144.90196166, 160.59564889,
#          160.34501193, 136.65366359]),
#   ('EF v3.1',
#    'climate change: biogenic',
#    'global warming potential (GWP100)'): array([0.12995154, 0.10333784, 0.13306509, 0.12129114, 0.09651128,
#          0.0974894 , 0.09279903, 0.1248303 , 0.09803389, 0.0886134 ]),
#   ('EF v3.1',
#    'climate change: fossil',
#    'global warming potential (GWP100)'): array([130.44145352, 154.18428027, 177.2515554 , 151.36513142,
#          166.04007646, 190.68393645, 144.76278979, 160.40858132,
#          160.18421742, 136.51589976]),
#   ('EF v3.1',
#    'climate change: land use and land use change',
#    'global warming potential (GWP100)'): array([0.06205187, 0.12580579, 0.06260814, 0.07164676, 0.0398387 ,
#          0.04415303, 0.04637285, 0.06223726, 0.06276063, 0.04915043]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater',
#    'comparative toxic unit for ecosystems (CTUe)'): array([ 8365.9710216 ,  1679.89509935, 10575.3735945 , 12521.77568752,
#           2090.6860489 , -5640.87042195,   537.21108518,   853.43684028,
#          -2738.4443732 ,  -977.25761822]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, inorganics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([ 8315.44850209,  1638.19329868, 10535.01095411, 12464.17506205,
#           2065.20301411, -5684.42339288,   509.96758431,   810.68561567,
#          -2779.53546296, -1010.45196622]),
#   ('EF v3.1',
#    'ecotoxicity: freshwater, organics',
#    'comparative toxic unit for ecosystems (CTUe)'): array([50.52251952, 41.70180067, 40.36264039, 57.60062547, 25.48303479,
#          43.55297093, 27.24350087, 42.75122461, 41.09108976, 33.19434799]),
#   ('EF v3.1',
#    'energy resources: non-renewable',
#    'abiotic depletion potential (ADP): fossil fuels'): array([1884.89493174, 2153.59863683, 2086.38618744, 2055.25307947,
#          1939.59208373, 2499.01459267, 2136.21056612, 1900.7851614 ,
#          2161.59180574, 1677.36282065]),
#   ('EF v3.1',
#    'eutrophication: freshwater',
#    'fraction of nutrients reaching freshwater end compartment (P)'): array([0.02197393, 0.01127172, 0.01763664, 0.0089815 , 0.01106961,
#          0.00666585, 0.00882152, 0.00333284, 0.00938785, 0.00703862]),
#   ('EF v3.1',
#    'eutrophication: marine',
#    'fraction of nutrients reaching marine end compartment (N)'): array([0.54659385, 0.55972142, 0.49547277, 0.45515657, 0.54658372,
#          0.48620182, 0.5782155 , 0.68588245, 0.65132057, 0.77753281]),
#   ('EF v3.1',
#    'eutrophication: terrestrial',
#    'accumulated exceedance (AE)'): array([5.93610226, 6.04133478, 5.34495193, 4.93514832, 5.87959657,
#          5.27010469, 6.22684121, 7.46316346, 7.0693828 , 8.47284544]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([ 2.05795970e-06, -6.62174600e-07,  2.27826996e-06,  2.28882356e-06,
#          -1.26233708e-07, -5.89110869e-07, -1.36736299e-06,  5.93967107e-07,
#          -1.64477944e-06,  6.83267748e-07]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([ 2.01172282e-06, -6.87262765e-07,  2.23541166e-06,  2.25873284e-06,
#          -1.53284046e-07, -6.17149001e-07, -1.40611033e-06,  5.54145554e-07,
#          -1.68673338e-06,  6.53750249e-07]),
#   ('EF v3.1',
#    'human toxicity: carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([4.62368855e-08, 2.50881650e-08, 4.28582953e-08, 3.00907205e-08,
#          2.70503383e-08, 2.80381320e-08, 3.87473355e-08, 3.98215528e-08,
#          4.19539411e-08, 2.95174993e-08]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic',
#    'comparative toxic unit for human (CTUh)'): array([ 5.00060818e-04,  5.48342945e-07,  7.11669971e-04,  8.27310028e-04,
#           3.93210484e-05, -4.26559353e-04, -1.76224356e-05,  3.03824730e-06,
#          -4.94832283e-04,  4.81428819e-06]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, inorganics',
#    'comparative toxic unit for human (CTUh)'): array([ 4.99988849e-04,  6.31962308e-07,  7.11576336e-04,  8.27283033e-04,
#           3.95504022e-05, -4.26664725e-04, -1.76898983e-05,  2.98556484e-06,
#          -4.94944193e-04,  4.73332442e-06]),
#   ('EF v3.1',
#    'human toxicity: non-carcinogenic, organics',
#    'comparative toxic unit for human (CTUh)'): array([ 7.19686575e-08, -8.36193636e-08,  9.36354031e-08,  2.69954330e-08,
#          -2.29353771e-07,  1.05372290e-07,  6.74627717e-08,  5.26824647e-08,
#           1.11910478e-07,  8.09637677e-08]),
#   ('EF v3.1',
#    'ionising radiation: human health',
#    'human exposure efficiency relative to u235'): array([2.07828648, 1.1865787 , 2.18029617, 2.00210784, 4.32778163,
#          3.13183512, 1.24063657, 1.0434979 , 1.11979804, 1.77422984]),
#   ('EF v3.1',
#    'land use',
#    'soil quality index'): array([819.68109941, 405.9621604 , 513.89650806, 475.95065909,
#          315.93437353, 415.26694823, 511.82432324, 494.28739285,
#          397.23175492, 466.43798601]),
#   ('EF v3.1',
#    'material resources: metals/minerals',
#    'abiotic depletion potential (ADP): elements (ultimate reserves)'): array([ 0.00127593, -0.00173319,  0.00144827, -0.00077687, -0.00453501,
#           0.00189972,  0.00081274,  0.00043581,  0.0017824 ,  0.00099774]),
#   ('EF v3.1',
#    'ozone depletion',
#    'ozone depletion potential (ODP)'): array([2.04418655e-06, 2.47193460e-06, 2.69405449e-06, 2.24992380e-06,
#          2.88650768e-06, 2.91121955e-06, 2.76520770e-06, 2.16079357e-06,
#          2.11501227e-06, 2.82441762e-06]),
#   ('EF v3.1',
#    'particulate matter formation',
#    'impact on human health'): array([4.46815639e-06, 4.83258257e-06, 4.57596434e-06, 5.27971333e-06,
#          5.67835495e-06, 4.44223502e-06, 4.83779359e-06, 4.10656661e-06,
#          5.55639072e-06, 3.60858657e-06]),
#   ('EF v3.1',
#    'photochemical oxidant formation: human health',
#    'tropospheric ozone concentration increase'): array([1.77974036, 1.77367971, 1.63004209, 1.52825904, 1.83331563,
#          1.66191028, 1.99813005, 2.07475654, 2.05704393, 2.39186884]),
#   ('EF v3.1',
#    'water use',
#    'user deprivation potential (deprivation-weighted water consumption)'): array([8.74751861, 7.4840857 , 8.90225301, 9.15314454, 8.15412076,
#          9.84809427, 8.22919151, 6.74855739, 8.1131586 , 8.19435047])}}
